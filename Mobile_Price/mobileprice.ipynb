# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Mobile Price Prediction Datatset.csv')
df
# Out:
#      Unnamed: 0                         Brand me  Ratings   RAM    ROM  \
# 0             0            LG V30+ (Black, 128 )      4.3   4.0  128.0
# 1             1                       I Kall K11      3.4   6.0   64.0
# 2             2                     Nokia 105 ss      4.3   4.0    4.0
# 3             3  Samsung Galaxy A50 (White, 64 )      4.4   6.0   64.0
# 4             4       POCO F1 (Steel Blue, 128 )      4.5   6.0  128.0
# ..          ...                              ...      ...   ...    ...
# 831         831             Karbonn K24 Plus Pro      3.8   6.0   32.0
# 832         832                  InFocus POWER 2      4.1   8.0   64.0
# 833         833  Alcatel 5V (Spectrum Blue, 32 )      4.4   3.0   32.0
# 834         834                      JIVI JV 12M      3.7  10.0   32.0
# 835         835                  Blacear B5 Grip      3.5   6.0   32.0
#
#      Mobile_Size  Primary_Cam  Selfi_Cam  Battery_Power  Price
# ...

# %%
df.shape
# Out:
# (836, 10)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Brand me', 'Ratings', 'RAM', 'ROM', 'Mobile_Size',
#        'Primary_Cam', 'Selfi_Cam', 'Battery_Power', 'Price'],
#       dtype='object')

# %%
df.head()
# Out:
#    Unnamed: 0                         Brand me  Ratings  RAM    ROM  \
# 0           0            LG V30+ (Black, 128 )      4.3  4.0  128.0
# 1           1                       I Kall K11      3.4  6.0   64.0
# 2           2                     Nokia 105 ss      4.3  4.0    4.0
# 3           3  Samsung Galaxy A50 (White, 64 )      4.4  6.0   64.0
# 4           4       POCO F1 (Steel Blue, 128 )      4.5  6.0  128.0
#
#    Mobile_Size  Primary_Cam  Selfi_Cam  Battery_Power  Price
# 0         6.00           48       13.0           4000  24999
# 1         4.50           48       12.0           4000  15999
# 2         4.50           64       16.0           4000  15000
# 3         6.40           48       15.0           3800  18999
# 4         6.18           35       15.0           3800  18999

# %%
df.tail()
# Out:
#      Unnamed: 0                         Brand me  Ratings   RAM   ROM  \
# 831         831             Karbonn K24 Plus Pro      3.8   6.0  32.0
# 832         832                  InFocus POWER 2      4.1   8.0  64.0
# 833         833  Alcatel 5V (Spectrum Blue, 32 )      4.4   3.0  32.0
# 834         834                      JIVI JV 12M      3.7  10.0  32.0
# 835         835                  Blacear B5 Grip      3.5   6.0  32.0
#
#      Mobile_Size  Primary_Cam  Selfi_Cam  Battery_Power  Price
# 831         4.54           48       12.0           2800   1299
# 832         4.54           64        NaN           2500   1390
# 833         6.20           48        1.0           3800   9790
# 834         4.50           64        NaN           3500    799
# 835         4.50           64       15.0           1050    799

# %%
df.dtypes
# Out:
# Unnamed: 0         int64
# Brand me          object
# Ratings          float64
# RAM              float64
# ROM              float64
# Mobile_Size      float64
# Primary_Cam        int64
# Selfi_Cam        float64
# Battery_Power      int64
# Price              int64
# dtype: object

# %%
df.isna().sum()
# Out:
# Unnamed: 0         0
# Brand me           0
# Ratings           31
# RAM                7
# ROM                4
# Mobile_Size        2
# Primary_Cam        0
# Selfi_Cam        269
# Battery_Power      0
# Price              0
# dtype: int64

# %%
df.corr(numeric_only=True)
# Out:
#                Unnamed: 0   Ratings       RAM       ROM  Mobile_Size  \
# Unnamed: 0       1.000000  0.036258 -0.002807  0.041192    -0.014559
# Ratings          0.036258  1.000000  0.101002  0.458957     0.089091
# RAM             -0.002807  0.101002  1.000000  0.252041    -0.001280
# ROM              0.041192  0.458957  0.252041  1.000000     0.108141
# Mobile_Size     -0.014559  0.089091 -0.001280  0.108141     1.000000
# Primary_Cam      0.048192 -0.098439  0.141025 -0.070019    -0.059971
# Selfi_Cam        0.064597 -0.176199  0.211169 -0.116891    -0.062876
# Battery_Power   -0.009143  0.478596  0.023227  0.410130     0.131636
# Price           -0.010725  0.367021  0.236988  0.255682     0.049087
#
#                Primary_Cam  Selfi_Cam  Battery_Power     Price
# Unnamed: 0        0.048192   0.064597      -0.009143 -0.010725
# Ratings          -0.098439  -0.176199       0.478596  0.367021
# RAM               0.141025   0.211169       0.023227  0.236988
# ...

# %%
sns.heatmap(df.corr(numeric_only=True))
# Out:
# <Axes: >

# %%
df.drop(['Unnamed: 0','Primary_Cam','Selfi_Cam'],axis=1,inplace=True)

# %%
sns.pairplot(df,kind='reg')

# %%
df.isna().sum()
# Out:
# Brand me          0
# Ratings          31
# RAM               7
# ROM               4
# Mobile_Size       2
# Battery_Power     0
# Price             0
# dtype: int64

# %%
df['ROM'].unique()
# Out:
# array([128. ,  64. ,   4. , 256. ,  32. ,  16. ,  24. ,  12. ,  56. ,
#          nan,  20. ,   2.4,  25. ,  40. ,  22. ,   3. ,   0. ,   2. ,
#         15. ,  10. ,  35. ,  51. ,   8. ])

# %%
df['Ratings']=df['Ratings'].fillna(df['Ratings'].mean())
df['RAM']=df['RAM'].fillna(df['RAM'].mode()[0])
df['ROM']=df['ROM'].fillna(df['ROM'].mode()[0])
df['Mobile_Size']=df['Mobile_Size'].fillna(df['Mobile_Size'].mean())

# %%
df['Brand me'].value_counts()
# Out:
# Brand me
# Kechaoda A27                                  11
# Lava 34                                        8
# Jivi R21Plus                                   8
# Easyfone Star                                  8
# MTR Ferrari                                    7
#                                               ..
# I Kall K24 New Coo of Two Mobiles              1
# Huawei Y9 Prime 2019 (Sapphire Blue, 128 )     1
# ITEL magic 1 max                               1
# Samsung Galaxy A80 (Ghost White, 128 )         1
# I Kall K 54                                    1
# Name: count, Length: 427, dtype: int64

# %%
len(df['Brand me'].unique())
# Out:
# 427

# %%
df['Brand']=df['Brand me'].apply(lambda x:x.split()[0])
df
# Out:
#                             Brand me  Ratings   RAM    ROM  Mobile_Size  \
# 0              LG V30+ (Black, 128 )      4.3   4.0  128.0         6.00
# 1                         I Kall K11      3.4   6.0   64.0         4.50
# 2                       Nokia 105 ss      4.3   4.0    4.0         4.50
# 3    Samsung Galaxy A50 (White, 64 )      4.4   6.0   64.0         6.40
# 4         POCO F1 (Steel Blue, 128 )      4.5   6.0  128.0         6.18
# ..                               ...      ...   ...    ...          ...
# 831             Karbonn K24 Plus Pro      3.8   6.0   32.0         4.54
# 832                  InFocus POWER 2      4.1   8.0   64.0         4.54
# 833  Alcatel 5V (Spectrum Blue, 32 )      4.4   3.0   32.0         6.20
# 834                      JIVI JV 12M      3.7  10.0   32.0         4.50
# 835                  Blacear B5 Grip      3.5   6.0   32.0         4.50
#
#      Battery_Power  Price    Brand
# 0             4000  24999       LG
# ...

# %%
df['Brand'].value_counts()
# Out:
# Brand
# Samsung     70
# I           61
# Kechaoda    49
# OPPO        47
# Micax       42
#             ..
# Mafe         1
# Infinix      1
# Motorola     1
# tecno        1
# Huawei       1
# Name: count, Length: 71, dtype: int64

# %%
len(df['Brand'].unique())
# Out:
# 71

# %%
sns.boxplot(y='Ratings',data=df)
# Out:
# <Axes: ylabel='Ratings'>

# %%
def removal_boxplot(df,column,threshold):
    sns.boxplot(y='Ratings',data=df)
    plt.title('Original')
    plt.show()

    removed_otliars=df[df[column]>=threshold]
    sns.boxplot(y=removed_otliars[column])
    plt.title('Removed')
    plt.show()
    return removed_otliars
threshold_value=3
no_outliers=removal_boxplot(df,'Ratings',threshold_value)

# %%
sns.boxplot(y='RAM',data=df)
# Out:
# <Axes: ylabel='RAM'>

# %%
Q1 = df['RAM'].quantile(0.25)
Q3 = df['RAM'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df=df[(df['RAM'] >= lower_bound) & (df['RAM'] <= upper_bound)]
sns.boxplot(data=df['RAM'])
plt.title("Boxplot without Outliers")
plt.show()

# %%
sns.boxplot(y='ROM',data=df)
# Out:
# <Axes: ylabel='ROM'>

# %%
sns.boxplot(y=df['Battery_Power'],data=df)
# Out:
# <Axes: ylabel='Battery_Power'>

# %%
Q1 = df['Battery_Power'].quantile(0.25)
Q3 = df['Battery_Power'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df=df[(df['Battery_Power'] >= lower_bound) & (df['Battery_Power'] <= upper_bound)]
sns.boxplot(data=df['Battery_Power'])
plt.title("Boxplot without Outliers")
plt.show()

# %%
sns.boxplot(y='Mobile_Size',data=df)
plt.title('Box plot with outliers')
# Out:
# Text(0.5, 1.0, 'Box plot with outliers')

# %%
Q1 = df['Mobile_Size'].quantile(0.25)
Q3 = df['Mobile_Size'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df=df[(df['Mobile_Size'] >= lower_bound) & (df['Mobile_Size'] <= upper_bound)]
sns.boxplot(data=df['Mobile_Size'])
plt.title("Boxplot without Outliers")
plt.show()

# %%
#encoding
dfe=pd.get_dummies(df[['Brand']],drop_first=True,dtype=int)
dfe
# Out:
#      Brand_BlackZone  Brand_Detel  Brand_Dublin  Brand_Easyfone  Brand_Ecotel  \
# 1                  0            0             0               0             0
# 10                 0            0             0               0             0
# 13                 0            0             0               1             0
# 22                 0            0             0               0             0
# 23                 0            0             0               0             0
# ..               ...          ...           ...             ...           ...
# 819                0            0             0               0             0
# 823                0            0             0               0             0
# 826                0            0             0               1             0
# 830                0            0             0               0             0
# 831                0            0             0               0             0
#
# ...

# %%
df1=pd.concat([df,dfe],axis=1)
df1
# Out:
#                  Brand me  Ratings  RAM   ROM  Mobile_Size  Battery_Power  \
# 1              I Kall K11      3.4  6.0  64.0         4.50           4000
# 10            Megus Ultra      3.9  6.0  32.0         4.54           4100
# 13          Easyfone Star      3.8  6.0  32.0         4.70           3000
# 22     Karbonn K451 Power      3.8  6.0  32.0         4.54           3000
# 23             Micax X742      3.8  6.0  32.0         4.54           3000
# ..                    ...      ...  ...   ...          ...            ...
# 819               Jivi N3      4.1  6.0  32.0         4.54           3500
# 823              Lava 34       4.0  6.0  32.0         4.54           2500
# 826        Easyfone Amico      3.5  6.0  32.0         4.52           3500
# 830        InFocus Vibe 1      3.6  6.0  32.0         4.50           3000
# 831  Karbonn K24 Plus Pro      3.8  6.0  32.0         4.54           2800
#
#      Price     Brand  Brand_BlackZone  Brand_Detel  ...  Brand_Micax  \
# ...

# %%
df1.drop(['Brand me','Brand'],axis=1,inplace=True)
df1
# Out:
#      Ratings  RAM   ROM  Mobile_Size  Battery_Power  Price  Brand_BlackZone  \
# 1        3.4  6.0  64.0         4.50           4000  15999                0
# 10       3.9  6.0  32.0         4.54           4100   1099                0
# 13       3.8  6.0  32.0         4.70           3000   3999                0
# 22       3.8  6.0  32.0         4.54           3000   1349                0
# 23       3.8  6.0  32.0         4.54           3000   1240                0
# ..       ...  ...   ...          ...            ...    ...              ...
# 819      4.1  6.0  32.0         4.54           3500    949                0
# 823      4.0  6.0  32.0         4.54           2500   1695                0
# 826      3.5  6.0  32.0         4.52           3500   2599                0
# 830      3.6  6.0  32.0         4.50           3000    898                0
# 831      3.8  6.0  32.0         4.54           2800   1299                0
#
# ...

# %%
x=df1.drop(['Price'],axis=1)
x
# Out:
#      Ratings  RAM   ROM  Mobile_Size  Battery_Power  Brand_BlackZone  \
# 1        3.4  6.0  64.0         4.50           4000                0
# 10       3.9  6.0  32.0         4.54           4100                0
# 13       3.8  6.0  32.0         4.70           3000                0
# 22       3.8  6.0  32.0         4.54           3000                0
# 23       3.8  6.0  32.0         4.54           3000                0
# ..       ...  ...   ...          ...            ...              ...
# 819      4.1  6.0  32.0         4.54           3500                0
# 823      4.0  6.0  32.0         4.54           2500                0
# 826      3.5  6.0  32.0         4.52           3500                0
# 830      3.6  6.0  32.0         4.50           3000                0
# 831      3.8  6.0  32.0         4.54           2800                0
#
#      Brand_Detel  Brand_Dublin  Brand_Easyfone  Brand_Ecotel  ...  \
# 1              0             0               0             0  ...
# ...

# %%
y=df['Price']
y
# Out:
# 1      15999
# 10      1099
# 13      3999
# 22      1349
# 23      1240
#        ...
# 819      949
# 823     1695
# 826     2599
# 830      898
# 831     1299
# Name: Price, Length: 243, dtype: int64

# %%
#train test
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=0)

# %%
#model creation
from sklearn.tree import DecisionTreeRegressor
model=DecisionTreeRegressor(criterion='absolute_error')
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
y_pred
# Out:
# array([ 980. ,  749. , 1099. ,  649. ,  980. , 1111. , 3399. ,  899. ,
#        1799. , 1695. ,  870. ,  980. , 1339.5, 1200. , 1099. , 1349. ,
#        1149. ,  995. , 1299. ,  950. , 3999. ,  898. , 1339.5,  970. ,
#         649. ,  735. , 1149. , 1099. , 2599. ,  898. ,  899. ,  980. ,
#         985. , 1399. , 1149. , 1111. ,  649. ,  980. , 1099. ,  919. ,
#        1299. , 1099. , 3999. , 3149. ,  970. ,  930. ,  985. , 1599. ,
#         599. , 1499. , 1149. , 2100. , 1699. , 1339.5, 1200. , 1699. ,
#         980. ,  649. , 1089. , 1339.5,  985. ,  649. ,  890. ,  899. ,
#         949. , 1695. , 1695. ,  930. ,  599. ,  649. ,  599. , 1240. ,
#         970. ])

# %%
import joblib
joblib.dump(model,'model.pkl')
joblib.dump(x.columns.tolist(), 'feature_names.pkl')
# Out:
# ['feature_names.pkl']

# %%
y_test
# Out:
# 346     982
# 502     749
# 128     639
# 220     599
# 345    1099
#        ...
# 254    1199
# 716     645
# 219    1099
# 23     1240
# 338     935
# Name: Price, Length: 73, dtype: int64

# %%
#DataFrame
df3=pd.DataFrame({'Actual_Value':y_test,'Predicted_Value':y_pred})
df3
# Out:
#      Actual_Value  Predicted_Value
# 346           982            980.0
# 502           749            749.0
# 128           639           1099.0
# 220           599            649.0
# 345          1099            980.0
# ..            ...              ...
# 254          1199            599.0
# 716           645            649.0
# 219          1099            599.0
# 23           1240           1240.0
# 338           935            970.0
#
# [73 rows x 2 columns]

# %%
#perfomance
from sklearn.metrics import mean_absolute_error,mean_absolute_percentage_error,mean_squared_error,root_mean_squared_error,r2_score
print('Mean absolute error: ',mean_absolute_error(y_test,y_pred))
print('mean_squared_error: ',mean_squared_error(y_test,y_pred))
print('root_mean_squared_error: ',root_mean_squared_error(y_test,y_pred))
print('Mean absolute percentage error:  ',mean_absolute_percentage_error(y_test,y_pred))
print('r2 score: ',r2_score(y_test,y_pred))
# Out:
# Mean absolute error:  113.26027397260275
# mean_squared_error:  43186.068493150684
# root_mean_squared_error:  207.81258020906887
# Mean absolute percentage error:   0.12990405090410564
# r2 score:  0.9093968423100306
